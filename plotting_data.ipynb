# %% [markdown]
# # Uploading and reading data

# %%
# libraries
import numpy as np
import pandas as pd
import random
import seaborn as sns
sns.set(style="ticks", color_codes=True)
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA, KernelPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.manifold import Isomap
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import SpectralEmbedding
from sklearn.manifold import TSNE
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
#Reading data csv
df = pd.read_csv("dataB.csv")
df.drop(df.columns[[0]], axis = 1, inplace = True) 
df
# Out:
#       fea.1  fea.2  fea.3  fea.4  fea.5  fea.6  fea.7  fea.8  fea.9  fea.10  \
# 0         4      4      3      0      0      4      2      1      4       1
# 1         5      1      4      3      1      3      5      1      4       4
# 2         1      3      0      3      1      1      0      1      0       2
# 3         5      3      2      3      5      2      2      0      4       5
# 4         3      5      3      3      0      4      1      1      4       3
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 2061      4      0      3      0      4      0      4      3      1       2
# 2062      2      2      3      4      2      1      2      3      3       4
# 2063      2      3      2      3      1      2      5      5      5       0
# 2064      5      2      4      3      1      0      3      2      2       1
# 2065      3      3      1      3      2      5      4      2      2       4
#
# ...

# %% [markdown]
# # Kernel PCA

# %%
#Normalizing data and fitting Kernel PCA model
X = df.values
y = df.loc[:,['gnd']].values

X = StandardScaler().fit_transform(X)

kpca = KernelPCA(n_components=2, kernel="rbf")
kpca = kpca.fit_transform(X)

# %% [markdown]
# # Isomap

# %%
isomap = Isomap(n_components=2)
isomap = isomap.fit_transform(X)

# %% [markdown]
# # Locally Linear Embedding (LLE)

# %%
lle = LocallyLinearEmbedding(n_components=2)
lle = lle.fit_transform(X)

# %% [markdown]
# # Laplacian Eigenmap

# %%
laplacianEigen = SpectralEmbedding(n_components=2)
laplacianEigen = laplacianEigen.fit_transform(X)

# %% [markdown]
# # t-SNE

# %%
tsne = TSNE(n_components=2)
tsne = tsne.fit_transform(X)

# %% [markdown]
# # KPCA Plot

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Component 1', fontsize = 15)
ax.set_ylabel('Component 2', fontsize = 15)
ax.set_title('Kernel PCA', fontsize = 20)

kpca = kpca.transpose()


ax.scatter(kpca[0],kpca[1])

ax.grid()

# %% [markdown]
# # Isomap Plot

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Component 1', fontsize = 15)
ax.set_ylabel('Component 2', fontsize = 15)
ax.set_title('Isomap', fontsize = 20)

isomap = isomap.transpose()


ax.scatter(isomap[0],isomap[1])

ax.grid()

# %% [markdown]
# # LLE Plot

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Component 1', fontsize = 15)
ax.set_ylabel('Component 2', fontsize = 15)
ax.set_title('LLE', fontsize = 20)

lle = lle.transpose()


ax.scatter(lle[0],lle[1])

ax.grid()

# %% [markdown]
# # Laplacian Eigenmap

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Component 1', fontsize = 15)
ax.set_ylabel('Component 2', fontsize = 15)
ax.set_title('Laplacian Eigenmap', fontsize = 20)

ax.scatter(laplacianEigen[0],laplacianEigen[1])

ax.grid()

# %% [markdown]
# # t-SNE

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Component 1', fontsize = 15)
ax.set_ylabel('Component 2', fontsize = 15)
ax.set_title('t-SNE', fontsize = 20)

tsne = tsne.transpose()

ax.scatter(tsne[0],tsne[1])

ax.grid()
